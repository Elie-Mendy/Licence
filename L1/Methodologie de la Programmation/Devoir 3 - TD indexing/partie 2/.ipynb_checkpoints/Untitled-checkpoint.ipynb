# %%
texte = '8<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});mw.user.options.set({"variant":"fr"});});});</script> gagné'



def nett(txt):
    x = txt.find("<script>")
    if x > 1:
        i = txt.find("</script>")
        print(txt[i])
        return txt[i+9:]
    
texte = nett(texte)

texte
